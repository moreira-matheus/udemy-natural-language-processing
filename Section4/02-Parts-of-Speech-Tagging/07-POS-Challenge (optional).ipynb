# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../IMG/Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # POS Challenge - OPTIONAL
# Just for fun, we've developed a game to test your knowledge of Part of Speech tags. The object of the game is to write a body of text that contains as many different ** *fine-grained tags* ** as possible. The highest possible score is 100 (or thereabouts). Points are awarded for the number of unique tags used, and for the fewest possible tokens used. Below is an example. Feel free to post your results in the Q&A Forum for this lecture, and good luck!

# %%
# Perform standard imports
import spacy
nlp = spacy.load('en_core_web_sm')

# Import the game script
import game

# %%
# Enter your text here:
text = u"The quick brown fox jumped over the lazy dog's back."

# %%
with open('../../TextFiles/desolation-row.txt') as file:
    text = file.read()

# %%
# Make your Doc object and pass it into the scorer:
doc = nlp(text)
print(game.scorer(doc))
# Out:
# Unique tags: 33
# Tokens used: 812
# SCORE: 33
# CONGRATULATIONS!

# %% [markdown]
# ___

# %%
# For practice, visualize your fine-grained POS tags (shown in the third column):
print(f"{'TOKEN':{10}} {'COARSE':{8}} {'FINE':{6}} {'DESCRIPTION'}")
print(f"{'-----':{10}} {'------':{8}} {'----':{6}} {'-----------'}")

for token in doc:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# TOKEN      COARSE   FINE   DESCRIPTION
# -----      ------   ----   -----------
# They       PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# selling    VERB     VBG    verb, gerund or present participle
# postcards  NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# hanging    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# painting   VERB     VBG    verb, gerund or present participle
# the        DET      DT     determiner
# passports  NOUN     NNS    noun, plural
# brown      VERB     VBN    verb, past participle
#
#           SPACE           None
# The        DET      DT     determiner
# beauty     NOUN     NN     noun, singular or mass
# parlor     NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# filled     VERB     VBN    verb, past participle
# with       ADP      IN     conjunction, subordinating or preposition
# sailors    NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# the        DET      DT     determiner
# circus     NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# in         ADP      IN     conjunction, subordinating or preposition
# town       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Here       ADV      RB     adverb
# comes      VERB     VBZ    verb, 3rd person singular present
# the        DET      DT     determiner
# blind      ADJ      JJ     adjective
# commissioner NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# 've        VERB     VB     verb, base form
# got        VERB     VBN    verb, past participle
# him        PRON     PRP    pronoun, personal
# in         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# trance     NOUN     NN     noun, singular or mass
#
#           SPACE           None
# One        NUM      CD     cardinal number
# hand       NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# tied       VERB     VBN    verb, past participle
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# tight      ADJ      JJ     adjective
# -          PUNCT    HYPH   punctuation mark, hyphen
# rope       NOUN     NN     noun, singular or mass
# walker     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# the        DET      DT     determiner
# other      ADJ      JJ     adjective
# is         VERB     VBZ    verb, 3rd person singular present
# in         ADP      IN     conjunction, subordinating or preposition
# his        ADJ      PRP$   pronoun, possessive
# pants      NOUN     NNS    noun, plural
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# riot       NOUN     NN     noun, singular or mass
# squad      NOUN     NN     noun, singular or mass
# they       PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# restless   ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# need       VERB     VBP    verb, non-3rd person singular present
# somewhere  ADV      RB     adverb
# to         PART     TO     infinitival to
# go         VERB     VB     verb, base form
#
#           SPACE           None
# As         ADP      IN     conjunction, subordinating or preposition
# Lady       PROPN    NNP    noun, proper singular
# and        CCONJ    CC     conjunction, coordinating
# I          PRON     PRP    pronoun, personal
# look       VERB     VBP    verb, non-3rd person singular present
# out        PART     RP     adverb, particle
# tonight    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# from       ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Cinderella PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# she        PRON     PRP    pronoun, personal
# seems      VERB     VBZ    verb, 3rd person singular present
# so         ADV      RB     adverb
# easy       ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ``     opening quotation mark
# It         PRON     PRP    pronoun, personal
# takes      VERB     VBZ    verb, 3rd person singular present
# one        PRON     PRP    pronoun, personal
# to         PART     TO     infinitival to
# know       VERB     VB     verb, base form
# one        NUM      CD     cardinal number
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ''     closing quotation mark
# she        PRON     PRP    pronoun, personal
# smiles     VERB     VBZ    verb, 3rd person singular present
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# puts       VERB     VBZ    verb, 3rd person singular present
# her        ADJ      PRP$   pronoun, possessive
# hands      NOUN     NNS    noun, plural
# in         ADP      IN     conjunction, subordinating or preposition
# her        ADJ      PRP$   pronoun, possessive
# back       NOUN     NN     noun, singular or mass
# pockets    VERB     VBZ    verb, 3rd person singular present
# Bette      PROPN    NNP    noun, proper singular
# Davis      PROPN    NNP    noun, proper singular
# style      NOUN     NN     noun, singular or mass
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# in         ADP      IN     conjunction, subordinating or preposition
# comes      VERB     VBZ    verb, 3rd person singular present
# Romeo      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# 's         VERB     VBZ    verb, 3rd person singular present
# moaning    VERB     VBG    verb, gerund or present participle
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
# You        PRON     PRP    pronoun, personal
# Belong     VERB     VBP    verb, non-3rd person singular present
# to         ADP      IN     conjunction, subordinating or preposition
# Me         PRON     PRP    pronoun, personal
# I          PRON     PRP    pronoun, personal
# Believe    VERB     VBP    verb, non-3rd person singular present
# "          PUNCT    ``     opening quotation mark
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# someone    NOUN     NN     noun, singular or mass
# says       VERB     VBZ    verb, 3rd person singular present
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ``     opening quotation mark
# You        PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# wrong      ADJ      JJ     adjective
# place      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# my         ADJ      PRP$   pronoun, possessive
# friend     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# you        PRON     PRP    pronoun, personal
# 'd         VERB     MD     verb, modal auxiliary
# better     ADV      RB     adverb
# leave      VERB     VB     verb, base form
# "          PUNCT    ``     opening quotation mark
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# only       ADJ      JJ     adjective
# sound      NOUN     NN     noun, singular or mass
# that       ADJ      WDT    wh-determiner
# 's         VERB     VBZ    verb, 3rd person singular present
# left       VERB     VBN    verb, past participle
# after      ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# ambulances NOUN     NNS    noun, plural
# go         VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# Is         VERB     VBZ    verb, 3rd person singular present
# Cinderella PROPN    NNP    noun, proper singular
# sweeping   VERB     VBG    verb, gerund or present participle
# up         PART     RP     adverb, particle
# on         ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Now        ADV      RB     adverb
# the        DET      DT     determiner
# moon       NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# almost     ADV      RB     adverb
# hidden     VERB     VBN    verb, past participle
# ,          PUNCT    ,      punctuation mark, comma
# the        DET      DT     determiner
# stars      NOUN     NNS    noun, plural
# are        VERB     VBP    verb, non-3rd person singular present
# beginning  VERB     VBG    verb, gerund or present participle
# to         PART     TO     infinitival to
# hide       VERB     VB     verb, base form
#
#           SPACE           None
# The        DET      DT     determiner
# fortune    NOUN     NN     noun, singular or mass
# telling    VERB     VBG    verb, gerund or present participle
# lady       NOUN     NN     noun, singular or mass
# has        VERB     VBZ    verb, 3rd person singular present
# even       ADV      RB     adverb
# taken      VERB     VBN    verb, past participle
# all        ADJ      PDT    predeterminer
# her        ADJ      PRP$   pronoun, possessive
# things     NOUN     NNS    noun, plural
# inside     ADV      RB     adverb
#
#           SPACE           None
# All        ADV      RB     adverb
# except     ADP      IN     conjunction, subordinating or preposition
# for        ADP      IN     conjunction, subordinating or preposition
# Cain       PROPN    NNP    noun, proper singular
# and        CCONJ    CC     conjunction, coordinating
# Abel       PROPN    NNP    noun, proper singular
# and        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# hunchback  NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# Notre      PROPN    NNP    noun, proper singular
# Dame       PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Everybody  NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# making     VERB     VBG    verb, gerund or present participle
# love       NOUN     NN     noun, singular or mass
# or         CCONJ    CC     conjunction, coordinating
# else       ADV      RB     adverb
# expecting  VERB     VBG    verb, gerund or present participle
# rain       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# Good       PROPN    NNP    noun, proper singular
# Samaritan  PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# 's         VERB     VBZ    verb, 3rd person singular present
# dressing   VERB     VBG    verb, gerund or present participle
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# 's         VERB     VBZ    verb, 3rd person singular present
# getting    VERB     VBG    verb, gerund or present participle
# ready      ADJ      JJ     adjective
# for        ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# show       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# He         PRON     PRP    pronoun, personal
# 's         VERB     VBZ    verb, 3rd person singular present
# going      VERB     VBG    verb, gerund or present participle
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# carnival   NOUN     NN     noun, singular or mass
# tonight    NOUN     NN     noun, singular or mass
# on         ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Ophelia    PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# she        PRON     PRP    pronoun, personal
# 's         VERB     VBZ    verb, 3rd person singular present
# '          PUNCT    ``     opening quotation mark
# neath      ADV      RB     adverb
# the        DET      DT     determiner
# window     NOUN     NN     noun, singular or mass
# for        ADP      IN     conjunction, subordinating or preposition
# her        PRON     PRP    pronoun, personal
# I          PRON     PRP    pronoun, personal
# feel       VERB     VBP    verb, non-3rd person singular present
# so         ADV      RB     adverb
# afraid     ADJ      JJ     adjective
#
#           SPACE           None
# On         ADP      IN     conjunction, subordinating or preposition
# her        ADJ      PRP$   pronoun, possessive
# twenty     NUM      CD     cardinal number
# -          PUNCT    HYPH   punctuation mark, hyphen
# second     ADJ      JJ     adjective
# birthday   NOUN     NN     noun, singular or mass
# she        PRON     PRP    pronoun, personal
# already    ADV      RB     adverb
# is         VERB     VBZ    verb, 3rd person singular present
# an         DET      DT     determiner
# old        ADJ      JJ     adjective
# maid       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# To         ADP      IN     conjunction, subordinating or preposition
# her        PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# death      NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# quite      ADV      RB     adverb
# romantic   ADJ      JJ     adjective
# she        PRON     PRP    pronoun, personal
# wears      VERB     VBZ    verb, 3rd person singular present
# an         DET      DT     determiner
# iron       NOUN     NN     noun, singular or mass
# vest       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Her        ADJ      PRP$   pronoun, possessive
# profession NOUN     NN     noun, singular or mass
# 's         PART     POS    possessive ending
# her        ADJ      PRP$   pronoun, possessive
# religion   NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# her        ADJ      PRP$   pronoun, possessive
# sin        NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# her        ADJ      PRP$   pronoun, possessive
# lifelessness ADJ      JJ     adjective
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# though     ADP      IN     conjunction, subordinating or preposition
# her        ADJ      PRP$   pronoun, possessive
# eyes       NOUN     NNS    noun, plural
# are        VERB     VBP    verb, non-3rd person singular present
# fixed      VERB     VBN    verb, past participle
# upon       ADP      IN     conjunction, subordinating or preposition
# Noah       PROPN    NNP    noun, proper singular
# 's         PART     POS    possessive ending
# great      ADJ      JJ     adjective
# rainbow    NOUN     NN     noun, singular or mass
#
#           SPACE           None
# She        PRON     PRP    pronoun, personal
# spends     VERB     VBZ    verb, 3rd person singular present
# her        ADJ      PRP$   pronoun, possessive
# time       NOUN     NN     noun, singular or mass
# peeking    VERB     VBG    verb, gerund or present participle
# into       ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Einstein   PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# disguised  VERB     VBN    verb, past participle
# as         ADP      IN     conjunction, subordinating or preposition
# Robin      PROPN    NNP    noun, proper singular
# Hood       PROPN    NNP    noun, proper singular
# with       ADP      IN     conjunction, subordinating or preposition
# his        ADJ      PRP$   pronoun, possessive
# memories   NOUN     NNS    noun, plural
# in         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# trunk      NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Passed     VERB     VBD    verb, past tense
# this       DET      DT     determiner
# way        NOUN     NN     noun, singular or mass
# an         DET      DT     determiner
# hour       NOUN     NN     noun, singular or mass
# ago        ADV      RB     adverb
# with       ADP      IN     conjunction, subordinating or preposition
# his        ADJ      PRP$   pronoun, possessive
# friend     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# a          DET      DT     determiner
# jealous    ADJ      JJ     adjective
# monk       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Now        ADV      RB     adverb
# he         PRON     PRP    pronoun, personal
# looked     VERB     VBD    verb, past tense
# so         ADV      RB     adverb
# immaculately ADV      RB     adverb
# frightful  ADJ      JJ     adjective
# as         ADP      IN     conjunction, subordinating or preposition
# he         PRON     PRP    pronoun, personal
# bummed     VERB     VBD    verb, past tense
# a          DET      DT     determiner
# cigarette  NOUN     NN     noun, singular or mass
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# he         PRON     PRP    pronoun, personal
# when       ADV      WRB    wh-adverb
# off        PART     RP     adverb, particle
# sniffing   VERB     VBG    verb, gerund or present participle
# drainpipes NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# reciting   VERB     VBG    verb, gerund or present participle
# the        DET      DT     determiner
# alphabet   NOUN     NN     noun, singular or mass
#
#           SPACE           None
# You        PRON     PRP    pronoun, personal
# would      VERB     MD     verb, modal auxiliary
# not        ADV      RB     adverb
# think      VERB     VB     verb, base form
# to         PART     TO     infinitival to
# look       VERB     VB     verb, base form
# at         ADP      IN     conjunction, subordinating or preposition
# him        PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# but        CCONJ    CC     conjunction, coordinating
# he         PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# famous     ADJ      JJ     adjective
# long       ADV      RB     adverb
# ago        ADV      RB     adverb
#
#           SPACE           None
# For        ADP      IN     conjunction, subordinating or preposition
# playing    VERB     VBG    verb, gerund or present participle
# the        DET      DT     determiner
# electric   ADJ      JJ     adjective
# violin     NOUN     NN     noun, singular or mass
# on         ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Dr.        PROPN    NNP    noun, proper singular
# Filth      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# keeps      VERB     VBZ    verb, 3rd person singular present
# his        ADJ      PRP$   pronoun, possessive
# world      NOUN     NN     noun, singular or mass
# inside     ADV      RB     adverb
# of         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# leather    NOUN     NN     noun, singular or mass
# cup        NOUN     NN     noun, singular or mass
#
#           SPACE           None
# But        CCONJ    CC     conjunction, coordinating
# all        ADJ      PDT    predeterminer
# his        ADJ      PRP$   pronoun, possessive
# sexless    ADJ      JJ     adjective
# patients   NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# trying     VERB     VBG    verb, gerund or present participle
# to         PART     TO     infinitival to
# blow       VERB     VB     verb, base form
# it         PRON     PRP    pronoun, personal
# up         PART     RP     adverb, particle
#
#           SPACE           None
# Now        ADV      RB     adverb
# his        ADJ      PRP$   pronoun, possessive
# nurse      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# some       DET      DT     determiner
# local      ADJ      JJ     adjective
# loser      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# she        PRON     PRP    pronoun, personal
# 's         VERB     VBZ    verb, 3rd person singular present
# in         ADP      IN     conjunction, subordinating or preposition
# charge     NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# cyanide    NOUN     NN     noun, singular or mass
# hole       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# she        PRON     PRP    pronoun, personal
# also       ADV      RB     adverb
# keeps      VERB     VBZ    verb, 3rd person singular present
# the        DET      DT     determiner
# cards      NOUN     NNS    noun, plural
# that       ADJ      WDT    wh-determiner
# read       VERB     VBP    verb, non-3rd person singular present
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ``     opening quotation mark
# Have       VERB     VBP    verb, non-3rd person singular present
# Mercy      NOUN     NN     noun, singular or mass
# on         ADP      IN     conjunction, subordinating or preposition
# His        ADJ      PRP$   pronoun, possessive
# Soul       PROPN    NNP    noun, proper singular
# "          PUNCT    ''     closing quotation mark
#
#           SPACE           None
# They       PRON     PRP    pronoun, personal
# all        DET      DT     determiner
# play       VERB     VBP    verb, non-3rd person singular present
# on         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# penny      NOUN     NN     noun, singular or mass
# whistles   NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# you        PRON     PRP    pronoun, personal
# can        VERB     MD     verb, modal auxiliary
# hear       VERB     VB     verb, base form
# them       PRON     PRP    pronoun, personal
# blow       VERB     VB     verb, base form
#
#           SPACE           None
# If         ADP      IN     conjunction, subordinating or preposition
# you        PRON     PRP    pronoun, personal
# lean       VERB     VBP    verb, non-3rd person singular present
# your       ADJ      PRP$   pronoun, possessive
# head       NOUN     NN     noun, singular or mass
# out        PART     RP     adverb, particle
# far        ADV      RB     adverb
# enough     ADV      RB     adverb
# from       ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Across     ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# street     NOUN     NN     noun, singular or mass
# they       PRON     PRP    pronoun, personal
# 've        VERB     VB     verb, base form
# nailed     VERB     VBN    verb, past participle
# the        DET      DT     determiner
# curtains   NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# getting    VERB     VBG    verb, gerund or present participle
# ready      ADJ      JJ     adjective
# for        ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# feast      NOUN     NN     noun, singular or mass
#
#           SPACE           None
# The        PROPN    NNP    noun, proper singular
# Phantom    PROPN    NNP    noun, proper singular
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# Opera      PROPN    NNP    noun, proper singular
# in         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# perfect    ADJ      JJ     adjective
# image      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# priest     NOUN     NN     noun, singular or mass
#
#           SPACE           None
# They       PRON     PRP    pronoun, personal
# are        VERB     VBP    verb, non-3rd person singular present
# spoon      VERB     VB     verb, base form
# feeding    VERB     VBG    verb, gerund or present participle
# Casanova   PROPN    NNP    noun, proper singular
# to         PART     TO     infinitival to
# get        VERB     VB     verb, base form
# him        PRON     PRP    pronoun, personal
# to         PART     TO     infinitival to
# feel       VERB     VB     verb, base form
# more       ADV      RBR    adverb, comparative
# assured    VERB     VBN    verb, past participle
#
#           SPACE           None
# Then       ADV      RB     adverb
# they       PRON     PRP    pronoun, personal
# 'll        VERB     MD     verb, modal auxiliary
# kill       VERB     VB     verb, base form
# him        PRON     PRP    pronoun, personal
# with       ADP      IN     conjunction, subordinating or preposition
# self       NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# confidence NOUN     NN     noun, singular or mass
# after      ADP      IN     conjunction, subordinating or preposition
# poisoning  VERB     VBG    verb, gerund or present participle
# him        PRON     PRP    pronoun, personal
# with       ADP      IN     conjunction, subordinating or preposition
# words      NOUN     NNS    noun, plural
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# Phantom    PROPN    NNP    noun, proper singular
# 's         PART     POS    possessive ending
# shouting   NOUN     NN     noun, singular or mass
# to         ADP      IN     conjunction, subordinating or preposition
# skinny     ADJ      JJ     adjective
# girls      NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ``     opening quotation mark
# Get        VERB     VB     verb, base form
# outta      NOUN     NN     noun, singular or mass
# here       ADV      RB     adverb
# if         ADP      IN     conjunction, subordinating or preposition
# you        PRON     PRP    pronoun, personal
# do         VERB     VBP    verb, non-3rd person singular present
# n't        ADV      RB     adverb
# know       VERB     VB     verb, base form
# "          PUNCT    ``     opening quotation mark
#
#           SPACE           None
# Casanova   PROPN    NNP    noun, proper singular
# is         VERB     VBZ    verb, 3rd person singular present
# just       ADV      RB     adverb
# being      VERB     VBG    verb, gerund or present participle
# punished   VERB     VBN    verb, past participle
# for        ADP      IN     conjunction, subordinating or preposition
# going      VERB     VBG    verb, gerund or present participle
# to         ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
# "          PUNCT    ''     closing quotation mark
#
#           SPACE           None
# At         ADP      IN     conjunction, subordinating or preposition
# midnight   NOUN     NN     noun, singular or mass
# all        ADJ      PDT    predeterminer
# the        DET      DT     determiner
# agents     NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# superhuman NOUN     NN     noun, singular or mass
# crew       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Come       VERB     VB     verb, base form
# out        PART     RP     adverb, particle
# and        CCONJ    CC     conjunction, coordinating
# round      VERB     VB     verb, base form
# up         PART     RP     adverb, particle
# everyone   NOUN     NN     noun, singular or mass
# that       ADJ      WDT    wh-determiner
# knows      VERB     VBZ    verb, 3rd person singular present
# more       ADJ      JJR    adjective, comparative
# than       ADP      IN     conjunction, subordinating or preposition
# they       PRON     PRP    pronoun, personal
# do         VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# Then       ADV      RB     adverb
# they       PRON     PRP    pronoun, personal
# bring      VERB     VBP    verb, non-3rd person singular present
# them       PRON     PRP    pronoun, personal
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# factory    NOUN     NN     noun, singular or mass
# where      ADV      WRB    wh-adverb
# the        DET      DT     determiner
# heart      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# attack     NOUN     NN     noun, singular or mass
# machine    NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Is         VERB     VBZ    verb, 3rd person singular present
# strapped   VERB     VBN    verb, past participle
# across     ADP      IN     conjunction, subordinating or preposition
# their      ADJ      PRP$   pronoun, possessive
# shoulders  NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# then       ADV      RB     adverb
# the        DET      DT     determiner
# kerosene   NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Is         VERB     VBZ    verb, 3rd person singular present
# brought    VERB     VBN    verb, past participle
# down       PART     RP     adverb, particle
# from       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# castles    NOUN     NNS    noun, plural
# by         ADP      IN     conjunction, subordinating or preposition
# insurance  NOUN     NN     noun, singular or mass
# men        NOUN     NNS    noun, plural
# who        NOUN     WP     wh-pronoun, personal
# go         VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# Check      NOUN     NN     noun, singular or mass
# to         PART     TO     infinitival to
# see        VERB     VB     verb, base form
# that       ADP      IN     conjunction, subordinating or preposition
# nobody     NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# escaping   VERB     VBG    verb, gerund or present participle
# to         ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# Praise     NOUN     NN     noun, singular or mass
# be         VERB     VB     verb, base form
# to         ADP      IN     conjunction, subordinating or preposition
# Nero       PROPN    NNP    noun, proper singular
# 's         PART     POS    possessive ending
# Neptune    PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# the        DET      DT     determiner
# Titanic    ADJ      JJ     adjective
# sails      NOUN     NNS    noun, plural
# at         ADP      IN     conjunction, subordinating or preposition
# dawn       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Everybody  PROPN    NNP    noun, proper singular
# 's         PART     POS    possessive ending
# shouting   NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ``     opening quotation mark
# Which      ADJ      WDT    wh-determiner
# side       NOUN     NN     noun, singular or mass
# are        VERB     VBP    verb, non-3rd person singular present
# you        PRON     PRP    pronoun, personal
# on         ADP      IN     conjunction, subordinating or preposition
# ?          PUNCT    .      punctuation mark, sentence closer
# !          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# Ezra       PROPN    NNP    noun, proper singular
# Pound      PROPN    NNP    noun, proper singular
# and        CCONJ    CC     conjunction, coordinating
# T.S.       PROPN    NNP    noun, proper singular
# Eliot      ADJ      JJ     adjective
# fighting   NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# captain    NOUN     NN     noun, singular or mass
# 's         PART     POS    possessive ending
# tower      NOUN     NN     noun, singular or mass
#
#           SPACE           None
# While      ADP      IN     conjunction, subordinating or preposition
# calypso    NOUN     NN     noun, singular or mass
# singers    NOUN     NNS    noun, plural
# laugh      VERB     VBP    verb, non-3rd person singular present
# at         ADP      IN     conjunction, subordinating or preposition
# them       PRON     PRP    pronoun, personal
# and        CCONJ    CC     conjunction, coordinating
# fishermen  NOUN     NNS    noun, plural
# hold       VERB     VBP    verb, non-3rd person singular present
# flowers    NOUN     NNS    noun, plural
#
#           SPACE           None
# Between    ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# windows    NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# sea        NOUN     NN     noun, singular or mass
# where      ADV      WRB    wh-adverb
# lovely     ADJ      JJ     adjective
# mermaids   NOUN     NNS    noun, plural
# flow       VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# nobody     NOUN     NN     noun, singular or mass
# has        VERB     VBZ    verb, 3rd person singular present
# to         PART     TO     infinitival to
# think      VERB     VB     verb, base form
# too        ADV      RB     adverb
# much       ADJ      JJ     adjective
# about      ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Yes        INTJ     UH     interjection
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# received   VERB     VBD    verb, past tense
# your       ADJ      PRP$   pronoun, possessive
# letter     NOUN     NN     noun, singular or mass
# yesterday  NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# about      ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# time       NOUN     NN     noun, singular or mass
# the        DET      DT     determiner
# doorknob   NOUN     NN     noun, singular or mass
# broke      VERB     VBD    verb, past tense
#
#           SPACE           None
# When       ADV      WRB    wh-adverb
# you        PRON     PRP    pronoun, personal
# asked      VERB     VBD    verb, past tense
# me         PRON     PRP    pronoun, personal
# how        ADV      WRB    wh-adverb
# I          PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# doing      VERB     VBG    verb, gerund or present participle
# ,          PUNCT    ,      punctuation mark, comma
# was        VERB     VBD    verb, past tense
# that       ADP      IN     conjunction, subordinating or preposition
# some       DET      DT     determiner
# kind       NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# joke       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# All        ADJ      PDT    predeterminer
# these      DET      DT     determiner
# people     NOUN     NNS    noun, plural
# that       ADJ      WDT    wh-determiner
# you        PRON     PRP    pronoun, personal
# mention    VERB     VBP    verb, non-3rd person singular present
# ,          PUNCT    ,      punctuation mark, comma
# yes        INTJ     UH     interjection
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# know       VERB     VBP    verb, non-3rd person singular present
# them       PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# 're        VERB     VBP    verb, non-3rd person singular present
# quite      ADV      RB     adverb
# lame       ADJ      JJ     adjective
#
#           SPACE           None
# I          PRON     PRP    pronoun, personal
# had        VERB     VBD    verb, past tense
# to         PART     TO     infinitival to
# rearrange  VERB     VB     verb, base form
# their      ADJ      PRP$   pronoun, possessive
# faces      NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# give       VERB     VB     verb, base form
# them       PRON     PRP    pronoun, personal
# all        ADJ      PDT    predeterminer
# another    DET      DT     determiner
# name       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# Right      ADV      RB     adverb
# now        ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# ca         VERB     MD     verb, modal auxiliary
# n't        ADV      RB     adverb
# read       VERB     VB     verb, base form
# too        ADV      RB     adverb
# good       ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# do         VERB     VB     verb, base form
# n't        ADV      RB     adverb
# send       VERB     VB     verb, base form
# me         PRON     PRP    pronoun, personal
# no         ADV      RB     adverb
# more       ADJ      JJR    adjective, comparative
# letters    NOUN     NNS    noun, plural
# no         DET      DT     determiner
#
#           SPACE           None
# Not        ADV      RB     adverb
# unless     ADP      IN     conjunction, subordinating or preposition
# you        PRON     PRP    pronoun, personal
# mail       VERB     VBP    verb, non-3rd person singular present
# them       PRON     PRP    pronoun, personal
# from       ADP      IN     conjunction, subordinating or preposition
# Desolation PROPN    NNP    noun, proper singular
# Row        PROPN    NNP    noun, proper singular
#
#           SPACE           None

# %% [markdown]
# ___
# ## Fine-grained Part-of-speech Tags
#
# <table>
# <tr><th></th><th>Coarse POS Tag</th><th>Description</th><th>Fine-grained Tag</th><th>Description</th><th>Morphology</th></tr>
# <tr><td>1.</td><td>ADJ</td><td>adjective</td><td>AFX</td><td>affix</td><td>Hyph=yes</td></tr>
# <tr><td>2.</td><td>ADJ</td><td></td><td>JJ</td><td>adjective</td><td>Degree=pos</td></tr>
# <tr><td>3.</td><td>ADJ</td><td></td><td>JJR</td><td>adjective, comparative</td><td>Degree=comp</td></tr>
# <tr><td>4.</td><td>ADJ</td><td></td><td>JJS</td><td>adjective, superlative</td><td>Degree=sup</td></tr>
# <tr><td>5.</td><td>ADJ</td><td></td><td>PDT</td><td>predeterminer</td><td>AdjType=pdt PronType=prn</td></tr>
# <tr><td>6.</td><td>ADJ</td><td></td><td>PRP\$</td><td>pronoun, possessive</td><td>PronType=prs Poss=yes</td></tr>
# <tr><td>7.</td><td>ADJ</td><td></td><td>WDT</td><td>wh-determiner</td><td>PronType=int rel</td></tr>
# <tr><td>8.</td><td>ADJ</td><td></td><td>WP\$</td><td>wh-pronoun, possessive</td><td>Poss=yes PronType=int rel</td></tr>
# <tr><td>9.</td><td>ADP</td><td>adposition</td><td>IN</td><td>conjunction, subordinating or preposition</td><td></td></tr>
# <tr><td>10.</td><td>ADV</td><td>adverb</td><td>EX</td><td>existential there</td><td>AdvType=ex</td></tr>
# <tr><td>11.</td><td>ADV</td><td></td><td>RB</td><td>adverb</td><td>Degree=pos</td></tr>
# <tr><td>12.</td><td>ADV</td><td></td><td>RBR</td><td>adverb, comparative</td><td>Degree=comp</td></tr>
# <tr><td>13.</td><td>ADV</td><td></td><td>RBS</td><td>adverb, superlative</td><td>Degree=sup</td></tr>
# <tr><td>14.</td><td>ADV</td><td></td><td>WRB</td><td>wh-adverb</td><td>PronType=int rel</td></tr>
# <tr><td>15.</td><td>CONJ</td><td>conjunction</td><td>CC</td><td>conjunction, coordinating</td><td>ConjType=coor</td></tr>
# <tr><td>16.</td><td>DET</td><td>determiner</td><td>DT</td><td></td><td>determiner</td></tr>
# <tr><td>17.</td><td>INTJ</td><td>interjection</td><td>UH</td><td>interjection</td><td></td></tr>
# <tr><td>18.</td><td>NOUN</td><td>noun</td><td>NN</td><td>noun, singular or mass</td><td>Number=sing</td></tr>
# <tr><td>19.</td><td>NOUN</td><td></td><td>NNS</td><td>noun, plural</td><td>Number=plur</td></tr>
# <tr><td>20.</td><td>NOUN</td><td></td><td>WP</td><td>wh-pronoun, personal</td><td>PronType=int rel</td></tr>
# <tr><td>21.</td><td>NUM</td><td>numeral</td><td>CD</td><td>cardinal number</td><td>NumType=card</td></tr>
# <tr><td>22.</td><td>PART</td><td>particle</td><td>POS</td><td>possessive ending</td><td>Poss=yes</td></tr>
# <tr><td>23.</td><td>PART</td><td></td><td>RP</td><td>adverb, particle</td><td></td></tr>
# <tr><td>24.</td><td>PART</td><td></td><td>TO</td><td>infinitival to</td><td>PartType=inf VerbForm=inf</td></tr>
# <tr><td>25.</td><td>PRON</td><td>pronoun</td><td>PRP</td><td>pronoun, personal</td><td>PronType=prs</td></tr>
# <tr><td>26.</td><td>PROPN</td><td>proper noun</td><td>NNP</td><td>noun, proper singular</td><td>NounType=prop Number=sign</td></tr>
# <tr><td>27.</td><td>PROPN</td><td></td><td>NNPS</td><td>noun, proper plural</td><td>NounType=prop Number=plur</td></tr>
# <tr><td>28.</td><td>PUNCT</td><td>punctuation</td><td>-LRB-</td><td>left round bracket</td><td>PunctType=brck PunctSide=ini</td></tr>
# <tr><td>29.</td><td>PUNCT</td><td></td><td>-RRB-</td><td>right round bracket</td><td>PunctType=brck PunctSide=fin</td></tr>
# <tr><td>30.</td><td>PUNCT</td><td></td><td>,</td><td>punctuation mark, comma</td><td>PunctType=comm</td></tr>
# <tr><td>31.</td><td>PUNCT</td><td></td><td>:</td><td>punctuation mark, colon or ellipsis</td><td></td></tr>
# <tr><td>32.</td><td>PUNCT</td><td></td><td>.</td><td>punctuation mark, sentence closer</td><td>PunctType=peri</td></tr>
# <tr><td>33.</td><td>PUNCT</td><td></td><td>''</td><td>closing quotation mark</td><td>PunctType=quot PunctSide=fin</td></tr>
# <tr><td>34.</td><td>PUNCT</td><td></td><td>""</td><td>closing quotation mark</td><td>PunctType=quot PunctSide=fin</td></tr>
# <tr><td>35.</td><td>PUNCT</td><td></td><td>``</td><td>opening quotation mark</td><td>PunctType=quot PunctSide=ini</td></tr>
# <tr><td>36.</td><td>PUNCT</td><td></td><td>HYPH</td><td>punctuation mark, hyphen</td><td>PunctType=dash</td></tr>
# <tr><td>37.</td><td>PUNCT</td><td></td><td>LS</td><td>list item marker</td><td>NumType=ord</td></tr>
# <tr><td>38.</td><td>PUNCT</td><td></td><td>NFP</td><td>superfluous punctuation</td><td></td></tr>
# <tr><td>39.</td><td>SYM</td><td>symbol</td><td>#</td><td>symbol, number sign</td><td>SymType=numbersign</td></tr>
# <tr><td>40.</td><td>SYM</td><td></td><td>\$</td><td>symbol, currency</td><td>SymType=currency</td></tr>
# <tr><td>41.</td><td>SYM</td><td></td><td>SYM</td><td>symbol</td><td></td></tr>
# <tr><td>42.</td><td>VERB</td><td>verb</td><td>BES</td><td>auxiliary "be"</td><td></td></tr>
# <tr><td>43.</td><td>VERB</td><td></td><td>HVS</td><td>forms of "have"</td><td></td></tr>
# <tr><td>44.</td><td>VERB</td><td></td><td>MD</td><td>verb, modal auxiliary</td><td>VerbType=mod</td></tr>
# <tr><td>45.</td><td>VERB</td><td></td><td>VB</td><td>verb, base form</td><td>VerbForm=inf</td></tr>
# <tr><td>46.</td><td>VERB</td><td></td><td>VBD</td><td>verb, past tense</td><td>VerbForm=fin Tense=past</td></tr>
# <tr><td>47.</td><td>VERB</td><td></td><td>VBG</td><td>verb, gerund or present participle</td><td>VerbForm=part Tense=pres Aspect=prog</td></tr>
# <tr><td>48.</td><td>VERB</td><td></td><td>VBN</td><td>verb, past participle</td><td>VerbForm=part Tense=past Aspect=perf</td></tr>
# <tr><td>49.</td><td>VERB</td><td></td><td>VBP</td><td>verb, non-3rd person singular present</td><td>VerbForm=fin Tense=pres</td></tr>
# <tr><td>50.</td><td>VERB</td><td></td><td>VBZ</td><td>verb, 3rd person singular present</td><td>VerbForm=fin Tense=pres Number=sing Person=3</td></tr>
# <tr><td>51.</td><td>X</td><td>other</td><td>ADD</td><td>email</td><td></td></tr>
# <tr><td>52.</td><td>X</td><td></td><td>FW</td><td>foreign word</td><td>Foreign=yes</td></tr>
# <tr><td>53.</td><td>X</td><td></td><td>GW</td><td>additional word in multi-word expression</td><td></td></tr>
# <tr><td>54.</td><td>X</td><td></td><td>XX</td><td>unknown</td><td></td></tr>
# <tr><td>55.</td><td>SPACE</td><td>space</td><td>_SP</td><td>space</td><td></td></tr>
# <tr><td>56.</td><td></td><td></td><td>NIL</td><td>missing tag</td><td></td></tr>
# </table>
